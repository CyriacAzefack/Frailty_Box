# %% [markdown]
# <h1>Stat_test</h1>

# %%
# %run -i "Behavior.py" -n toy_T0_0_change -w 28 -b start_time -m stat_test --plot
# Out:
# ERROR:root:File `'Behavior.py'` not found.

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T1_1_change -w 28 -b start_time -m stat_test --plot

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T2_2_changes -w 28 -b start_time -m stat_test --plot

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T3_3_changes -w 28 -b start_time -m stat_test --plot

# %% [markdown]
# <h1>Histogram Intersect</h1>

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T0_0_change -w 28 -b start_time -m histogram_intersect --plot

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T1_1_change -w 28 -b start_time -m histogram_intersect --plot

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T2_2_changes -w 28 -b start_time -m histogram_intersect --plot

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T3_3_changes -w 28 -b start_time -m histogram_intersect --plot

# %% [markdown]
# <h1>Features</h1>

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T0_0_change -w 28 -b start_time -m features --plot

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T1_1_change -w 28 -b start_time -m features --plot

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T2_2_changes -w 28 -b start_time -m features --plot

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T3_3_changes -w 28 -b start_time -m features --plot

# %% [markdown]
# <h1>Density Intersect</h1>

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T0_0_change -w 28 -b start_time -m density_intersect --plot
# Out:
# Dataset Name : TOY_T0_0_CHANGE
# Windows size : 28
# Behavior Type : Activity Occurrence Time
# Drift Method : density_intersect
# Display : True
# Mode debug : False
# ### Behavior Drift on 'Eating' ###
# C:\Users\cyriac.azefack\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Similarity Matrix Built
# Threshold: 0.8 inflation: 1.4 modularity: 0.0
# Threshold: 0.85 inflation: 1.4 modularity: 0.0
# Threshold: 0.9 inflation: 1.4 modularity: 0.0
# Threshold: 0.95 inflation: 1.4 modularity: 0.0
# Threshold : 0.8
# Inflation Power : 1.4
# 	#### Time elapsed for the clustering  : 	0:03:03.200000 ####
# ...

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T1_1_change -w 28 -b start_time -m density_intersect --plot
# Out:
# Dataset Name : TOY_T1_1_CHANGE
# Windows size : 28
# Behavior Type : Activity Occurrence Time
# Drift Method : density_intersect
# Display : True
# Mode debug : False
# ### Behavior Drift on 'Eating' ###
# C:\Users\cyriac.azefack\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Similarity Matrix Built
# Threshold: 0.8 inflation: 1.4 modularity: 0.4155356365219935
# Threshold: 0.85 inflation: 1.4 modularity: 0.41794890404993634
# Threshold: 0.9 inflation: 1.4 modularity: 0.44369647263753953
# Threshold: 0.95 inflation: 1.4 modularity: 0.46576063289301683
# Threshold : 0.95
# Inflation Power : 1.4
# ...

# %%
# %run -i "Data_Drift/Behavior.py" -n toy_T2_2_changes -w 28 -b start_time -m density_intersect --plot
# Out:
# Dataset Name : TOY_T2_2_CHANGES
# Windows size : 28
# Behavior Type : Activity Occurrence Time
# Drift Method : density_intersect
# Display : True
# Mode debug : False
# ### Behavior Drift on 'Eating' ###
# C:\Users\cyriac.azefack\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Similarity Matrix Built
# Threshold: 0.8 inflation: 1.4 modularity: 0.599424138629381
# Threshold: 0.85 inflation: 1.4 modularity: 0.6014845600471974
# Threshold: 0.9 inflation: 1.4 modularity: 0.5987197210506422
# Threshold: 0.95 inflation: 1.4 modularity: 0.6628745520344469
# Threshold : 0.95
# Inflation Power : 1.4
# ...

# %%
# %prun
# %run -i "Data_Drift/Behavior.py" -n toy_T3_3_changes -w 28 -b start_time -m density_intersect --plot --debug
# Out:
#  Dataset Name : TOY_T3_3_CHANGES
# Windows size : 28
# Behavior Type : Activity Occurrence Time
# Drift Method : density_intersect
# Display : True
# Mode debug : True
# ### Behavior Drift on 'Eating' ###
# C:\Users\cyriac.azefack\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Similarity Matrix Built
# Threshold: 0.8 inflation: 1.4 modularity: 0.0
# Threshold: 0.85 inflation: 1.4 modularity: 0.3949230657570035
# Threshold: 0.9 inflation: 1.4 modularity: 0.4055196690375966
# Threshold: 0.95 inflation: 1.4 modularity: 0.527416896501666
# Threshold : 0.95
# Inflation Power : 1.4
# ...
