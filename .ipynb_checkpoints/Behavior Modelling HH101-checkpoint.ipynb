# %%
import Behavior_Model as bm

# %%
args = "--dataset_name hh101 --time_step 30 --simu_step 5 --sim 10 --training_ratio 0.8 --tep 30 --window_days 7 --plot"
args = args.split(" ")

# %%
# %prun
bm.main(args)
# Out:
#  #         PARAMETERS         #
# Dataset Name : HH101
# Tep (mn): 30
# Training ratio : 0.8
# Static Learning (no time evolution) : False
# Time Window Duration : 7 days
# Simulation time step (mn) : 5
# ADP time step (mn) : 60
# Number of replications : 10
# Display Mode : True
# Debug Mode: False
# ##############################
# #     DYNAMIC LEARNING       #
# ##############################
#
#
# ##################################################
# ## Creation of the Macro-Activity '('enter_home', 'leave_home', 'watch_tv')' ##
# ####################################################
#
#
#
#
# ##################################################
# ## Creation of the Macro-Activity '('bathe', 'dress', 'toilet')' ##
# ####################################################
#
#
#
#
# ##################################################
# ## Creation of the Macro-Activity '('cook_breakfast', 'eat_breakfast', 'watch_tv')' ##
# ####################################################
#
#
#
#
# ...
