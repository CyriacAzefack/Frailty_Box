# 231  19-Mar-2008 09:48:29  19-Mar-2008 09:49:10         4         use toilet
# 232  19-Mar-2008 09:49:25  19-Mar-2008 10:00:23         5        take shower
# 233  19-Mar-2008 10:08:27  19-Mar-2008 17:15:17         1        leave house
# 234  19-Mar-2008 17:19:28  19-Mar-2008 17:22:04         5        take shower
# 235  19-Mar-2008 17:26:40  19-Mar-2008 20:20:07         1        leave house
# 236  19-Mar-2008 20:46:18  19-Mar-2008 20:49:02         4         use toilet
# 237  19-Mar-2008 21:49:09  19-Mar-2008 21:51:46         4         use toilet
# 238  19-Mar-2008 21:52:26  19-Mar-2008 21:53:56         6        brush teeth
# 239  19-Mar-2008 21:54:30  20-Mar-2008 08:31:03        10          go to bed
# 240  20-Mar-2008 00:35:07  20-Mar-2008 00:36:01         4         use toilet
# 241  20-Mar-2008 06:57:54  20-Mar-2008 06:58:39         4         use toilet
# 242  20-Mar-2008 08:45:42  20-Mar-2008 08:47:06         4         use toilet
# 243  20-Mar-2008 09:11:55  20-Mar-2008 09:15:14        13  prepare Breakfast
# 244  20-Mar-2008 09:42:26  20-Mar-2008 09:50:22         5        take shower
# 245  20-Mar-2008 09:56:47  20-Mar-2008 22:49:41         1        leave house
# 246  20-Mar-2008 22:51:11  20-Mar-2008 22:55:32         4         use toilet
# 247  20-Mar-2008 23:36:23  20-Mar-2008 23:41:10         4         use toilet
# 248  20-Mar-2008 23:56:36  20-Mar-2008 23:58:08         6        brush teeth
# 249  20-Mar-2008 23:58:42  20-Mar-2008 23:59:27         4         use toilet
# 250  20-Mar-2008 23:59:38  21-Mar-2008 09:04:25        10          go to bed
# 251  21-Mar-2008 03:49:46  21-Mar-2008 03:50:47         4         use toilet
# 252  21-Mar-2008 08:30:56  21-Mar-2008 08:31:36         4         use toilet
# 253  21-Mar-2008 09:13:22  21-Mar-2008 09:15:33         4         use toilet
# 254  21-Mar-2008 09:17:47  21-Mar-2008 09:24:43         5        take shower
# 255  21-Mar-2008 09:42:28  21-Mar-2008 15:51:38         1        leave house
# 256  21-Mar-2008 15:51:58  21-Mar-2008 15:53:10         4         use toilet
# 257  21-Mar-2008 17:03:48  21-Mar-2008 18:05:18        10          go to bed
# 258  21-Mar-2008 18:24:24  21-Mar-2008 18:25:05         4         use toilet
#
# [259 rows x 4 columns]

# %%
new_df = pd.DataFrame(columns=["date", "activity"])

date_format = '%d-%b-%Y %H:%M:%S'
for index, row in merged.iterrows():
    new_df.loc[len(new_df)] = [row["start_time"], row["label"]+" start"]
    new_df.loc[len(new_df)] = [row["end_time"],  row["label"]+" end"]


new_df['date'] = pd.to_datetime(new_df['date'], format=date_format)
new_df.sort_values(['date'], ascending=True, inplace=True)


new_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [brush teeth] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-cee4303203cd> in <module>()
#       3 date_format = '%d-%b-%Y %H:%M:%S'
#       4 for index, row in merged.iterrows():
# ----> 5     new_df.loc[len(new_df)] = [row["start_time"], labels.loc[row["label"], "activity"]+" start"]
#       6     new_df.loc[len(new_df)] = [row["end_time"],  labels.loc[row["label"], "activity"]+" end"]
#       7
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     834     def _getitem_tuple(self, tup):
#     835         try:
# --> 836             return self._getitem_lowerdim(tup)
#     837         except IndexingError:
#     838             pass
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     965         for i, key in enumerate(tup):
#     966             if is_label_like(key) or isinstance(key, tuple):
# --> 967                 section = self._getitem_axis(key, axis=i)
#     968
#     969                 # we have yielded a scalar ?
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1440                 raise
#    1441             except:
# -> 1442                 error()
#    1443
#    1444         return True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1427                                     "key")
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#    1431             try:
#
# KeyError: 'the label [brush teeth] is not in the [index]'

# %%
new_df.to_csv("KA_dataset.csv", sep=";", index=False)
new_df.to_csv("kaData.txt", sep=";", index=False)
