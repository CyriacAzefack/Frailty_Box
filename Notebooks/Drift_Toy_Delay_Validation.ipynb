# %%
import sys
sys.path.append("../")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
sns.set(font_scale=1.4) # for label size

# %%
results = pd.read_csv('../output/drift_toy_delay_results_w30_l10.csv')

results['delay_days'] += 30

results
# Out:
#      id  nb_drifts  silhouette  id_drift  delay_days
# 0    11          1    0.741583         0           4
# 1     0          1    0.707389         0          13
# 2     1          1    0.752505         0           7
# 3    10          1    0.687463         0          23
# 4    14          1    0.715606         0          10
# ..   ..        ...         ...       ...         ...
# 247  98          4    0.683673         3          20
# 248  99          4    0.659215         0          23
# 249  99          4    0.659215         1          17
# 250  99          4    0.659215         2          20
# 251  99          4    0.659215         3          18
#
# [252 rows x 5 columns]

# %%
sns.distplot(results.delay_days)
m = results.delay_days.mean()
plt.plot([m, m], [0, 0.07], linewidth=4, color='r')
plt.xlabel('Number of days')
plt.xticks(list(plt.xticks()[0]) + [m])
plt.xlim([-25, 50])
# Out:
# (-25, 50)

# %%
results.nb_drifts += 1
sns.boxplot(x="nb_drifts", y="delay_days", data=results, palette="Set1")
plt.ylim([-25, 50])
plt.xlabel('Number of behaviors present')
plt.ylabel('Delay (days)')
# Out:
# Text(0, 0.5, 'Delay (days)')

# %%
sns.distplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-69f1f606c476> in <module>
# ----> 1 sns.distplot()
#
# TypeError: distplot() missing 1 required positional argument: 'a'

# %%
sns.scatterplot(x='nb_drifts', y='silhouette', data=results)
